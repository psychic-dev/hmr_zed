# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D

# %%
data = pd.read_csv('/home/apg/Desktop/Recordings/right_knee_2019-05-17-13:08:26.csv', delimiter = ',', header=None)

# %%
z = np.linspace(0, 535, 10700)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot3D(data[0], data[1], z, 'gray')
plt.title('Right Knee')
plt.show()

# %%
data = pd.read_csv('/home/apg/Desktop/Recordings/left_knee_2019-05-17-13:08:26.csv', delimiter = ',', header=None)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot3D(data[0], data[1], z, 'gray')
plt.title('Left Knee')
plt.show()
